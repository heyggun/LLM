# %% [markdown]
# **How doese prompt engineering influence the output of LLMs?**

# %% [markdown]
#     Prompt engineering involves crafting input prompts to guide an LLM's output effectively. Since LLMs are highly sensitive to input phrasing, a well-designed prompt can significantly influence the quality and relevance of the response. For example, adding context or specific instructions within the prompt can improve accuracy in tasks like summarization or question-answering Prompt engineering is especially useful in zero-shot and few-shot learning scenarios, where task-specific examples are minimal.
#
# ![image.png](attachment:image.png)
#
#     - 프롬프트 엔지니어링은 LLM의 출력을 효과적으로 유도하기 위해 입력 프롬프트를 설계하는 과정이다.
#     LLM은 입력 표현 방식에 매우 민감하기 때문에, 잘 구성된 프롬프트는 응답의 품질과 관련성을 크게 향상시킬 수 있다.
#     예를 들어 프롬프트에 추가적인 컨텍스트나 구체적인 지시사항을 포함하면 요약이나 질의응답과 같은 작업에서 정확도를 높일 수 있다.
#     특히 프롬프트 엔지니어링은 작업별 예시가 제한적인 제로샷 및 퓨샷 러닝 상황에서 유용하게 활용된다.

# %% [markdown]
# **12. How can catastrophic forgetting be mitigated in large language models (LLMs)?**
#
#
#     Catastrophic forgetting happens when an LLM forgets previously learned tasks while learning new ones, which limits it versatility. To mitigate his, several strategies are used:
#
# ![image.png](attachment:image.png)
#
#     1. Rehearsal methods: These involve retraining the model on a mix of old and new data, helping it retrain knowledge of previous tasks.
#     2. Elastic Weight Consolidation (EWC) : This method assigns importance to certain model weights, protecting critical knowledge while learning new tasks.
#     3. Modular approaches: Techniques like progressive neural networks (ProgNet) and optimized fixed expansion layers (OFELs) introduce new modules for new tasks, allowing the LLM to learn without overwriting prior knowledge.
#
#
#     - 카타스트로픽 포겟팅(catastrophic forgetting) 은 LLM이 새로운 작업을 학습하는 과정에서 기존에 학습한 내용을 잊어버리는 현상으로,
#     모델의 범용성을 제한하는 주요 문제 중 하나이다. 이를 완화하기 위해 다음과 같은 전략이 사용된다.
#
#     1. 리허설 기법(Rehearsal methods) : 기존 데이터와 새로운 데이터를 혼합하여 모델을 다시 학습시키는 방법으로,
#     이전 작업에 대한 지식을 유지하는데 도움을 준다.
#     2. 탄력적 가중치 정합(Elastic Weight Concolidation, EWC) : 특정 모델 가중치에 중요도를 부여하여, 새로운 작업을 학습할 때도
#     핵심적인 기존 지식이 손실되지 않도록 보호하는 방법이다.
#     3. 모듈형 접근(Modular approaches) : 진행형 신경망(Progressive Neural Networks, ProNet)이나 최적화된 고정 확장 레이어(Optimized Fixed Exapnsion Layers, OFELs)와 같은 기법을 활용하여, 새로운 작업을 위한 별도 모듈을 추가하는 방식이다.
#     이를 통해 기존 지식을 덮어쓰지 않고 새로운 개념을 학습할 수 있다.
